# %%
import sys
# sys.path.insert(0, '/home/idv-eqs8-pza/IDV_code/Variational_GP/spatial_GP')
import time
import random
import csv
import numpy as np

import scipy.io
from scipy.io import loadmat

import torch
import pickle

from tqdm import tqdm
from tqdm import notebook

import matplotlib
import matplotlib.pyplot as plt

import importlib
import utils

# Enable autoreload
# %load_ext autoreload
# %autoreload 2
importlib.reload(utils)



TORCH_DTYPE = torch.float64 #NB: Basically all of the matrices in Spatial_GP have 1.e-7 added to the diagonal, to be changed if we want to use float64
torch.set_default_dtype(TORCH_DTYPE)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
torch.set_default_device(device)
print(f'Device is: {device}')

# Set seeds for reproducibility
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if you are using multi-GPU.
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark     = False


# with open('data/processed_data.pkl', 'wb') as f:
#     pickle.save(f)

# To compare with samuale use:
# save_pickle('pietro_data', **{'K_pietro':K, 'K_tilde_pietro':K_tilde})
# Out:
# Using device: cuda:0 (from utils.py)
# Using device: cuda:0 (from utils.py)
# Device is: cuda:0

# %% [markdown]
# ## Parameters of the training

# %%
rand_xtilde = True # If True, xtilde (inducing points) are chosen randomly, if False, xtilde is chosen from the first ntilde images

cellid  = 14             # Choose cell
ntilde  = 3            # Number of xtilde
kernfun = 'acosker' # Choose kernel function

nEstep  = 5             # Total number of E-steps iterations. Update on the variational parameters m and V, plus the parameters f_param of the link function
nMstep  = 5             # Total number of M-steps iterations. Update on the Hyperparameters of the kernel function
maxiter = 100          # Iterations of the optimization algorithm comprising M and E steps

# %% [markdown]
# ## Import the dataset and preprocess

# %%
# Import the data

# Open the .pkl dataset file for reading in binary mode (rb)
with open('/home/idv-eqs8-pza/IDV_code/Variational_GP/spatial_GP/Data/data2_41mixed_tr28.pkl', 'rb') as file:
    # Load the data from the file
    loaded_data = pickle.load(file)
    # loaded_data is a Dataset object from module Data with attributes "images_train, _val, _test" as well as responses

X_train = torch.tensor(loaded_data.images_train).to(device, dtype=TORCH_DTYPE) #shape (2910,108,108,1) where 108 is the number of pixels. 2910 is the amount of training data
X_val   = torch.tensor(loaded_data.images_val).to(device, dtype=TORCH_DTYPE)
X_test  = torch.tensor(loaded_data.images_test).to(device, dtype=TORCH_DTYPE) # shape (30,108,108,1) # nimages, npx, npx

R_train = torch.tensor(loaded_data.responses_train).to(device, dtype=TORCH_DTYPE) #shape (2910,41) 2910 is the amount of training data, 41 is the number of cells
R_val   = torch.tensor(loaded_data.responses_val).to(device, dtype=TORCH_DTYPE)
R_test  = torch.tensor(loaded_data.responses_test).to(device, dtype=TORCH_DTYPE) # shape (30,30,42) 30 repetitions, 30 images, 42 cells

# Concatenate Xtrain and Xval if not using validation set 
X = torch.cat( (X_train, X_val), axis=0,) #shape (3160,108,108,1)
R = torch.cat( (R_train, R_val), axis=0,)
# X = X_train
# R = R_train

# Choose a cell
r = R[:,cellid] # shape (nt,) where nt is the number of trials

# Reshape images to 1D vector
n_px_side = X.shape[1] # 108   
X = torch.reshape(X, ( X.shape[0], X.shape[1]*X.shape[2])) 
# If X_val is being used, reshape it
# X_val = torch.reshape(X_val, ( X_val.shape[0], X_val.shape[1]*X_val.shape[2])) # shape (n x val, 11664)=(nt, nx)

if rand_xtilde == True:
    ntilde_indices = torch.randint(0, X.shape[0], (ntilde,))
else:
    ntilde_indices = torch.arange(0,ntilde, dtype=torch.int64)

xtilde = X[ntilde_indices,:]

# %% [markdown]
# ## Choose starting values of parameters

# %%
# In this code the learnt hyperparameters are the one in the dictionary 'theta'
# One can set them direcly or let generate_theta() set them based on the training set STAs
# To override the choice of generate_theta() just give theta as input 

# If one wants to compare the hyperparemeters set in Matthews's / Samuels's code one has to set
# logbetasam : and transform it to logbetaexpr with the function fromlogbetasam_to_logbetaexpr
# logrhosam  : and transform it to logrhoexpr with the function fromlogrhosam_to_logrhoexpr
# logsigma_0 : and transform it to sigma_0 exponetiating it

# logbetaexpr = utils.fromlogbetasam_to_logbetaexpr( logbetasam=torch.tensor(5.5) )# Logbetaexpr in this code is equal to logbeta in Samuele's code. Samuele's code set logbeta to 5.5
# logrhoexpr  = utils.fromlogrhosam_to_logrhoexpr( logrhosam=torch.tensor(5)) 

# Alternatively one can directly set the hyperparameters to the values in the dictionary 'theta' below
# logbetaexpr = torch.tensor(4.65)
# logrhoexpr = torch.tensor(4.3)

# Or set them as beta and rho
# beta = torch.tensor(0.032)
# rho  = torch.tensor(0.076)
beta = torch.tensor(0.022)
rho  = torch.tensor(0.0045)
logbetaexpr = -2*torch.log(2*beta)
logrhoexpr  = -torch.log(2*rho*rho)

# Samuele's code set the log of sigma
logsigma_0 = torch.tensor(0) 
sigma_0    = torch.exp(logsigma_0)

# Amp is not present in Matthews original code
Amp = torch.tensor(1.0) 

# Center of receptive field
# eps_0x = torch.tensor(0.2)
# eps_0y = torch.tensor(-0.02)
eps_0x = torch.tensor(0.00)
eps_0y = torch.tensor(0.00)

# Hypermarameters, Are expected to be 0-dimensional tensors
theta = {'sigma_0'  : sigma_0,     'Amp': Amp,
        'eps_0x'    : eps_0x ,     'eps_0y'   : eps_0y, 
        '-2log2beta': logbetaexpr, '-log2rho2': logrhoexpr }
# theta = {'sigma_0': sigma_0, 'eps_0x':torch.tensor(torch.randn((1,)).item())*0.01 , 'eps_0y':torch.tensor(torch.randn((1,)).item())*0.01, 
                            # '-2log2beta': logbetaexpr, '-log2rho2': logrhoexpr, 'Amp': Amp }
# Set the gradient of the hyperparemters to be updateable 
for key, value in theta.items():
    # to exclude a single hyperparemeters from the optimization ( to exclude them all just set nMstep=0)
    # if key == 'eps_0x' or key == 'eps_0y':
        # continue
    theta[key] = value.requires_grad_()

# Generate the hyperparameters tuple
# If hyperparameters are set manually:
hyperparams_tuple = utils.generate_theta( x=X, r=r, n_px_side=n_px_side, display=True, **theta)
# If hyperparameters are set based on the STAs:
# hyperparams_tuple = utils.generate_theta( x=X, r=r, n_px_side=n_px_side, display=True)

# A        = torch.tensor(0.007)
A        = torch.tensor(0.007)
logA     = torch.log(A)
# lambda0  = torch.tensor(0.31)
lambda0  = torch.tensor(1)
f_params = {'logA': logA, 'loglambda0':torch.log(lambda0)}

# f_params = {'logA': logA, 'tanhlambda0':torch.tanh(lambda0)}



# f_params = {'logA': logA, 'lambda0':torch.tensor(0.31)}
# f_params = {'A': torch.tensor(0.0017), 'lambda0':torch.tensor(0.3697)}
# f_params = {'A': torch.tensor(-0.0807), 'lambda0': torch.tensor(0.3762)}


for key, value in f_params.items():
    f_params[key] = value.requires_grad_()

args = {
        'cellid': cellid,                       # sending also cellid to the fit function to make sure we dont lose track of it
        'ntilde':  ntilde,
        'maxiter': maxiter,
        'nMstep':  nMstep,
        'nEstep':  nEstep,
        'kernfun': kernfun,
        'n_px_side': n_px_side,
        'display_prog':  False,
        'hyperparams_tuple': hyperparams_tuple,
        'f_params': f_params,
        'xtilde': xtilde,
        'm': torch.zeros( (ntilde) )
        # 'm': torch.ones( (ntilde) )
        #'V': dont initialize V if you want it to be initialized as K_tilde and projected _exactly_ as K_tilde_b for stabilisation
    }
# Out:
# updated sigma_0 to 1.0000
# updated Amp to 1.0000
# updated eps_0x to 0.0000
# updated eps_0y to 0.0000
# updated -2log2beta to 6.2471
# updated -log2rho2 to 10.1142

# %% [markdown]
# ## Fit the model
# Also returns a tracking dictionary for important values

# %%
theta_fit, f_params_fit, m_b_fit, V_b_fit, C_fit, mask_fit, K_tilde_b_fit, K_tilde_inv_b_fit, B, fit_parameters, values_track_fit, err_dict = utils.varGP(X, r, **args)

# Save the model. All of the matrices are projected in the eigenspace of big eigenvalues of K_tilde. Indicated by _b
model_b = {
    'theta': theta_fit,
    'f_params': f_params_fit,
    'm_b': m_b_fit,
    'V_b': V_b_fit,
    'C'  : C_fit,
    'mask': mask_fit,
    'K_tilde_inv_b': K_tilde_inv_b_fit,
    'K_tilde_b': K_tilde_b_fit,
    'B': B,
    'values_track': values_track_fit,
}

for key in fit_parameters.keys():
    model_b[key] = fit_parameters[key]

if err_dict['is_error']:
    print('Error in the fit')
    raise err_dict['error']
# Out:
#  Before overloading
#  Hyperparameters have been SET as  : beta = 0.0586, rho = 0.0293
#  Samuele hyperparameters           : logbetasam = 4.9822, logrhosam = 7.0617
#
#  After overloading
#  Dict of learnable hyperparameters : sigma_0 = 1.0000, eps_0x = 0.0000, eps_0y = 0.0000, -2log2beta = 4.2891, -log2rho2 = 6.3685, Amp = 1.0000
#  Hyperparameters from the logexpr  : beta = 0.0586, rho = 0.0293
#  Samuele hyperparameters           : logbetasam = 4.9822, logrhosam = 7.0617
# Initialization took: 0.0451 seconds
#
# *Iteration*: 0
# Estep in iteration 0
#       KL_div = 390.6399
#       KL_div = 1.9684
#       KL_div = 11.4154
#       KL_div = 16.4941
#       KL_div = 16.4716
# Mstep in iteration 0
# *Iteration*: 1
# Estep in iteration 1
#       KL_div = 21.3962
#       KL_div = 20.2556
#       KL_div = 19.5999
#       KL_div = 19.2360
#       KL_div = 19.0287
# Mstep in iteration 1
# *Iteration*: 2
# Estep in iteration 2
#       KL_div = 25.5279
#       KL_div = 24.3916
#       KL_div = 23.6071
#       KL_div = 23.1250
#       KL_div = 22.8208
# Mstep in iteration 2
# *Iteration*: 3
# Estep in iteration 3
#       KL_div = 22.9675
#       KL_div = 22.7143
#       KL_div = 22.4490
#       KL_div = 22.2731
#       KL_div = 22.1548
# Mstep in iteration 3
# *Iteration*: 4
# Estep in iteration 4
#       KL_div = 22.0303
#       KL_div = 22.0302
#       KL_div = 22.0300
#       KL_div = 22.0300
#       KL_div = 22.0300
# Mstep in iteration 4
# *Iteration*: 5
# Estep in iteration 5
#       KL_div = 23.4642
#       KL_div = 23.0616
#       KL_div = 22.7955
#       KL_div = 22.6158
#       KL_div = 22.4944
# Mstep in iteration 5
# *Iteration*: 6
# Estep in iteration 6
#       KL_div = 22.3717
#       KL_div = 22.3607
#       KL_div = 22.3538
#       KL_div = 22.3491
#       KL_div = 22.3491
# Mstep in iteration 6
# *Iteration*: 7
# Estep in iteration 7
#       KL_div = 23.7081
#       KL_div = 23.3193
#       KL_div = 23.0569
#       KL_div = 22.8784
#       KL_div = 22.7567
# Mstep in iteration 7
# *Iteration*: 8
# Estep in iteration 8
#       KL_div = 22.6649
#       KL_div = 22.6527
#       KL_div = 22.6465
#       KL_div = 22.6422
#       KL_div = 22.6422
# Mstep in iteration 8
# *Iteration*: 9
# Estep in iteration 9
#       KL_div = 24.3096
#       KL_div = 23.8213
#       KL_div = 23.4888
#       KL_div = 23.2609
#       KL_div = 23.1043
# Mstep in iteration 9
# *Iteration*: 10
# Estep in iteration 10
#       KL_div = 23.1615
#       KL_div = 23.1117
#       KL_div = 23.0791
#       KL_div = 23.0566
#       KL_div = 23.0410
# Mstep in iteration 10
# *Iteration*: 11
# Estep in iteration 11
#       KL_div = 24.4098
#       KL_div = 24.0650
#       KL_div = 23.8304
#       KL_div = 23.6683
#       KL_div = 23.5560
# Mstep in iteration 11
# *Iteration*: 12
# Estep in iteration 12
#       KL_div = 23.3055
#       KL_div = 23.3111
#       KL_div = 23.3150
#       KL_div = 23.3178
#       KL_div = 23.3178
# Mstep in iteration 12
# *Iteration*: 13
# Estep in iteration 13
#       KL_div = 27.1697
#       KL_div = 25.9903
#       KL_div = 25.1787
#       KL_div = 24.6118
#       KL_div = 24.2121
# Mstep in iteration 13
# *Iteration*: 14
# Estep in iteration 14
#       KL_div = 25.1445
#       KL_div = 24.8345
#       KL_div = 24.6067
#       KL_div = 24.4435
#       KL_div = 24.3260
# Mstep in iteration 14
# *Iteration*: 15
# Estep in iteration 15
#       KL_div = 26.6340
#       KL_div = 26.2921
#       KL_div = 26.0467
#       KL_div = 25.8708
#       KL_div = 25.7445
# Mstep in iteration 15
# *Iteration*: 16
# Estep in iteration 16
#       KL_div = 27.5785
#       KL_div = 27.2892
#       KL_div = 27.0838
#       KL_div = 26.9365
#       KL_div = 26.8308
# Mstep in iteration 16
# *Iteration*: 17
# Estep in iteration 17
#       KL_div = 29.7463
#       KL_div = 29.3512
#       KL_div = 29.0684
#       KL_div = 28.8663
#       KL_div = 28.7219
# Mstep in iteration 17
# *Iteration*: 18
# Estep in iteration 18
#       KL_div = 30.5417
#       KL_div = 30.2873
#       KL_div = 30.1082
#       KL_div = 29.9805
#       KL_div = 29.8897
# Mstep in iteration 18
# *Iteration*: 19
# Estep in iteration 19
#       KL_div = 30.1017
#       KL_div = 30.0106
#       KL_div = 29.9451
#       KL_div = 29.8984
#       KL_div = 29.8652
# Mstep in iteration 19
# *Iteration*: 20
# Estep in iteration 20
#       KL_div = 32.4134
#       KL_div = 32.0548
#       KL_div = 31.7999
#       KL_div = 31.6184
#       KL_div = 31.4894
# Mstep in iteration 20
# *Iteration*: 21
# Estep in iteration 21
#       KL_div = 29.4951
#       KL_div = 29.6036
#       KL_div = 29.6820
#       KL_div = 29.7382
#       KL_div = 29.7784
# Mstep in iteration 21
# *Iteration*: 22
# Estep in iteration 22
#       KL_div = 32.5170
#       KL_div = 32.2560
#       KL_div = 32.0695
#       KL_div = 31.9367
#       KL_div = 31.8423
# Mstep in iteration 22
# *Iteration*: 23
# Estep in iteration 23
#       KL_div = 32.0226
#       KL_div = 31.9535
#       KL_div = 31.9078
#       KL_div = 31.8753
#       KL_div = 31.8523
# Mstep in iteration 23
# *Iteration*: 24
# Estep in iteration 24
#       KL_div = 32.2643
#       KL_div = 32.1957
#       KL_div = 32.1461
#       KL_div = 32.1110
#       KL_div = 32.0860
# Mstep in iteration 24
# *Iteration*: 25
# Estep in iteration 25
#       KL_div = 35.7744
#       KL_div = 35.3015
#       KL_div = 34.9647
#       KL_div = 34.7254
#       KL_div = 34.5560
# Mstep in iteration 25
# *Iteration*: 26
# Estep in iteration 26
#       KL_div = 33.4501
#       KL_div = 33.4606
#       KL_div = 33.4683
#       KL_div = 33.4738
#       KL_div = 33.4776
# Mstep in iteration 26
# *Iteration*: 27
# Estep in iteration 27
#       KL_div = 35.0766
#       KL_div = 34.8596
#       KL_div = 34.7060
#       KL_div = 34.5975
#       KL_div = 34.5210
# Mstep in iteration 27
# *Iteration*: 28
# Estep in iteration 28
#       KL_div = 33.3458
#       KL_div = 33.4162
#       KL_div = 33.4660
#       KL_div = 33.5011
#       KL_div = 33.5260
# Mstep in iteration 28
# *Iteration*: 29
# Estep in iteration 29
#       KL_div = 37.0867
#       KL_div = 36.7638
#       KL_div = 36.5378
#       KL_div = 36.3789
#       KL_div = 36.2674
# Mstep in iteration 29
# *Iteration*: 30
# Estep in iteration 30
#       KL_div = 33.6723
#       KL_div = 33.8245
#       KL_div = 33.9208
#       KL_div = 33.9886
#       KL_div = 34.0365
# Mstep in iteration 30
# *Iteration*: 31
# Estep in iteration 31
#       KL_div = 36.4112
#       KL_div = 36.1842
#       KL_div = 36.0251
#       KL_div = 35.9131
#       KL_div = 35.8344
# Mstep in iteration 31
# *Iteration*: 32
# Estep in iteration 32
#       KL_div = 34.4535
#       KL_div = 34.5368
#       KL_div = 34.5945
#       KL_div = 34.6352
#       KL_div = 34.6638
# Mstep in iteration 32
# *Iteration*: 33
# Estep in iteration 33
#       KL_div = 36.2127
#       KL_div = 36.0485
#       KL_div = 35.9331
#       KL_div = 35.8519
#       KL_div = 35.7948
# Mstep in iteration 33
# *Iteration*: 34
# Estep in iteration 34
#       KL_div = 34.7456
#       KL_div = 34.8122
#       KL_div = 34.8593
#       KL_div = 34.8925
#       KL_div = 34.9159
# Mstep in iteration 34
# *Iteration*: 35
# Estep in iteration 35
#       KL_div = 36.4148
#       KL_div = 36.2562
#       KL_div = 36.1448
#       KL_div = 36.0664
#       KL_div = 36.0114
# Mstep in iteration 35
# *Iteration*: 36
# Estep in iteration 36
#       KL_div = 35.0377
#       KL_div = 35.0980
#       KL_div = 35.1408
#       KL_div = 35.1709
#       KL_div = 35.1922
# Mstep in iteration 36
# *Iteration*: 37
# Estep in iteration 37
#       KL_div = 36.6165
#       KL_div = 36.4633
#       KL_div = 36.3558
#       KL_div = 36.2802
#       KL_div = 36.2271
# Mstep in iteration 37
# *Iteration*: 38
# Estep in iteration 38
#       KL_div = 35.2871
#       KL_div = 35.3456
#       KL_div = 35.3870
#       KL_div = 35.4162
#       KL_div = 35.4367
# Mstep in iteration 38
# *Iteration*: 39
# Estep in iteration 39
#       KL_div = 36.8157
#       KL_div = 36.6664
#       KL_div = 36.5616
#       KL_div = 36.4880
#       KL_div = 36.4363
# Mstep in iteration 39
# *Iteration*: 40
# Estep in iteration 40
#       KL_div = 35.5225
#       KL_div = 35.5795
#       KL_div = 35.6199
#       KL_div = 35.6483
#       KL_div = 35.6684
# Mstep in iteration 40
# *Iteration*: 41
# Estep in iteration 41
#       KL_div = 37.0044
#       KL_div = 36.8587
#       KL_div = 36.7565
#       KL_div = 36.6847
#       KL_div = 36.6343
# Mstep in iteration 41
# *Iteration*: 42
# Estep in iteration 42
#       KL_div = 35.7437
#       KL_div = 35.7995
#       KL_div = 35.8390
#       KL_div = 35.8668
#       KL_div = 35.8864
# Mstep in iteration 42
# *Iteration*: 43
# Estep in iteration 43
#       KL_div = 37.1828
#       KL_div = 37.0406
#       KL_div = 36.9408
#       KL_div = 36.8707
#       KL_div = 36.8215
# Mstep in iteration 43
# *Iteration*: 44
# Estep in iteration 44
#       KL_div = 35.9576
#       KL_div = 36.0118
#       KL_div = 36.0502
#       KL_div = 36.0772
#       KL_div = 36.0962
# Mstep in iteration 44
# *Iteration*: 45
# Estep in iteration 45
#       KL_div = 37.3532
#       KL_div = 37.2142
#       KL_div = 37.1167
#       KL_div = 37.0482
#       KL_div = 37.0001
# Mstep in iteration 45
# *Iteration*: 46
# Estep in iteration 46
#       KL_div = 36.1602
#       KL_div = 36.2130
#       KL_div = 36.2504
#       KL_div = 36.2767
#       KL_div = 36.2952
# Mstep in iteration 46
# *Iteration*: 47
# Estep in iteration 47
#       KL_div = 37.5149
#       KL_div = 37.3789
#       KL_div = 37.2836
#       KL_div = 37.2166
#       KL_div = 37.1696
# Mstep in iteration 47
# *Iteration*: 48
# Estep in iteration 48
#       KL_div = 36.3518
#       KL_div = 36.4034
#       KL_div = 36.4399
#       KL_div = 36.4656
#       KL_div = 36.4836
# Mstep in iteration 48
# *Iteration*: 49
# Estep in iteration 49
#       KL_div = 37.6684
#       KL_div = 37.5353
#       KL_div = 37.4420
#       KL_div = 37.3765
#       KL_div = 37.3306
# Mstep in iteration 49
# *Iteration*: 50
# Estep in iteration 50
#       KL_div = 36.5353
#       KL_div = 36.5856
#       KL_div = 36.6211
#       KL_div = 36.6462
#       KL_div = 36.6637
# Mstep in iteration 50
# *Iteration*: 51
# Estep in iteration 51
#       KL_div = 37.8146
#       KL_div = 37.6843
#       KL_div = 37.5930
#       KL_div = 37.5289
#       KL_div = 37.4839
# Mstep in iteration 51
# *Iteration*: 52
# Estep in iteration 52
#       KL_div = 36.7108
#       KL_div = 36.7597
#       KL_div = 36.7943
#       KL_div = 36.8186
#       KL_div = 36.8357
# Mstep in iteration 52
# *Iteration*: 53
# Estep in iteration 53
#       KL_div = 37.9537
#       KL_div = 37.8261
#       KL_div = 37.7366
#       KL_div = 37.6739
#       KL_div = 37.6298
# Mstep in iteration 53
# *Iteration*: 54
# Estep in iteration 54
#       KL_div = 36.8783
#       KL_div = 36.9260
#       KL_div = 36.9597
#       KL_div = 36.9833
#       KL_div = 37.0000
# Mstep in iteration 54
# *Iteration*: 55
# Estep in iteration 55
#       KL_div = 38.0865
#       KL_div = 37.9615
#       KL_div = 37.8739
#       KL_div = 37.8124
#       KL_div = 37.7692
# Mstep in iteration 55
# *Iteration*: 56
# Estep in iteration 56
#       KL_div = 37.0387
#       KL_div = 37.0851
#       KL_div = 37.1178
#       KL_div = 37.1409
#       KL_div = 37.1571
# Mstep in iteration 56
# *Iteration*: 57
# Estep in iteration 57
#       KL_div = 38.2132
#       KL_div = 38.0907
#       KL_div = 38.0048
#       KL_div = 37.9445
#       KL_div = 37.9023
# Mstep in iteration 57
# *Iteration*: 58
# Estep in iteration 58
#       KL_div = 37.1921
#       KL_div = 37.2372
#       KL_div = 37.2691
#       KL_div = 37.2915
#       KL_div = 37.3073
# Mstep in iteration 58
# *Iteration*: 59
# Estep in iteration 59
#       KL_div = 38.3340
#       KL_div = 38.2139
#       KL_div = 38.1298
#       KL_div = 38.0707
#       KL_div = 38.0293
# Mstep in iteration 59
# *Iteration*: 60
# Estep in iteration 60
#       KL_div = 37.3391
#       KL_div = 37.3830
#       KL_div = 37.4140
#       KL_div = 37.4358
#       KL_div = 37.4511
# Mstep in iteration 60
# *Iteration*: 61
# Estep in iteration 61
#       KL_div = 38.4493
#       KL_div = 38.3316
#       KL_div = 38.2491
#       KL_div = 38.1913
#       KL_div = 38.1506
# Mstep in iteration 61
# *Iteration*: 62
# Estep in iteration 62
#       KL_div = 37.4799
#       KL_div = 37.5225
#       KL_div = 37.5527
#       KL_div = 37.5739
#       KL_div = 37.5888
# Mstep in iteration 62
# *Iteration*: 63
# Estep in iteration 63
#       KL_div = 38.5596
#       KL_div = 38.4442
#       KL_div = 38.3633
#       KL_div = 38.3065
#       KL_div = 38.2667
# Mstep in iteration 63
# *Iteration*: 64
# Estep in iteration 64
#       KL_div = 37.6147
#       KL_div = 37.6562
#       KL_div = 37.6855
#       KL_div = 37.7061
#       KL_div = 37.7206
# Mstep in iteration 64
# *Iteration*: 65
# Estep in iteration 65
#       KL_div = 38.6652
#       KL_div = 38.5520
#       KL_div = 38.4726
#       KL_div = 38.4169
#       KL_div = 38.3778
# Mstep in iteration 65
# *Iteration*: 66
# Estep in iteration 66
#       KL_div = 37.7441
#       KL_div = 37.7844
#       KL_div = 37.8129
#       KL_div = 37.8329
#       KL_div = 37.8470
# Mstep in iteration 66
# *Iteration*: 67
# Estep in iteration 67
#       KL_div = 38.7659
#       KL_div = 38.6549
#       KL_div = 38.5771
#       KL_div = 38.5225
#       KL_div = 38.4841
# Mstep in iteration 67
# *Iteration*: 68
# Estep in iteration 68
#       KL_div = 37.8682
#       KL_div = 37.9073
#       KL_div = 37.9350
#       KL_div = 37.9544
#       KL_div = 37.9681
# Mstep in iteration 68
# *Iteration*: 69
# Estep in iteration 69
#       KL_div = 38.8625
#       KL_div = 38.7536
#       KL_div = 38.6773
#       KL_div = 38.6237
#       KL_div = 38.5860
# Mstep in iteration 69
# *Iteration*: 70
# Estep in iteration 70
#       KL_div = 37.9872
#       KL_div = 38.0252
#       KL_div = 38.0521
#       KL_div = 38.0710
#       KL_div = 38.0843
# Mstep in iteration 70
# *Iteration*: 71
# Estep in iteration 71
#       KL_div = 38.9549
#       KL_div = 38.8480
#       KL_div = 38.7731
#       KL_div = 38.7205
#       KL_div = 38.6836
# Mstep in iteration 71
# *Iteration*: 72
# Estep in iteration 72
#       KL_div = 38.1015
#       KL_div = 38.1384
#       KL_div = 38.1645
#       KL_div = 38.1829
#       KL_div = 38.1959
# Mstep in iteration 72
# *Iteration*: 73
# Estep in iteration 73
#       KL_div = 39.0434
#       KL_div = 38.9385
#       KL_div = 38.8650
#       KL_div = 38.8134
#       KL_div = 38.7771
# Mstep in iteration 73
# *Iteration*: 74
# Estep in iteration 74
#       KL_div = 38.2111
#       KL_div = 38.2470
#       KL_div = 38.2724
#       KL_div = 38.2903
#       KL_div = 38.3028
# Mstep in iteration 74
# *Iteration*: 75
# Estep in iteration 75
#       KL_div = 39.1283
#       KL_div = 39.0254
#       KL_div = 38.9532
#       KL_div = 38.9025
#       KL_div = 38.8669
# Mstep in iteration 75
# *Iteration*: 76
# Estep in iteration 76
#       KL_div = 38.3164
#       KL_div = 38.3513
#       KL_div = 38.3759
#       KL_div = 38.3933
#       KL_div = 38.4055
# Mstep in iteration 76
# *Iteration*: 77
# Estep in iteration 77
#       KL_div = 39.2097
#       KL_div = 39.1087
#       KL_div = 39.0378
#       KL_div = 38.9880
#       KL_div = 38.9531
# Mstep in iteration 77
# *Iteration*: 78
# Estep in iteration 78
#       KL_div = 38.4181
#       KL_div = 38.4519
#       KL_div = 38.4758
#       KL_div = 38.4927
#       KL_div = 38.5045
# Mstep in iteration 78
# *Iteration*: 79
# Estep in iteration 79
#       KL_div = 39.2881
#       KL_div = 39.1889
#       KL_div = 39.1193
#       KL_div = 39.0704
#       KL_div = 39.0360
# Mstep in iteration 79
# *Iteration*: 80
# Estep in iteration 80
#       KL_div = 38.5355
#       KL_div = 38.5665
#       KL_div = 38.5885
#       KL_div = 38.6040
#       KL_div = 38.6149
# Mstep in iteration 80
# *Iteration*: 81
# Estep in iteration 81
#       KL_div = 39.3764
#       KL_div = 39.2770
#       KL_div = 39.2072
#       KL_div = 39.1581
#       KL_div = 39.1236
# Mstep in iteration 81
# *Iteration*: 82
# Estep in iteration 82
#       KL_div = 38.5985
#       KL_div = 38.6321
#       KL_div = 38.6559
#       KL_div = 38.6727
#       KL_div = 38.6845
# Mstep in iteration 82
# *Iteration*: 83
# Estep in iteration 83
#       KL_div = 39.4430
#       KL_div = 39.3463
#       KL_div = 39.2784
#       KL_div = 39.2307
#       KL_div = 39.1971
# Mstep in iteration 83
# *Iteration*: 84
# Estep in iteration 84
#       KL_div = 38.6999
#       KL_div = 38.7312
#       KL_div = 38.7533
#       KL_div = 38.7689
#       KL_div = 38.7799
# Mstep in iteration 84
# *Iteration*: 85
# Estep in iteration 85
#       KL_div = 39.5082
#       KL_div = 39.4142
#       KL_div = 39.3481
#       KL_div = 39.3016
#       KL_div = 39.2689
# Mstep in iteration 85
# *Iteration*: 86
# Estep in iteration 86
#       KL_div = 38.7886
#       KL_div = 38.8187
#       KL_div = 38.8401
#       KL_div = 38.8552
#       KL_div = 38.8658
# Mstep in iteration 86
# *Iteration*: 87
# Estep in iteration 87
#       KL_div = 39.5752
#       KL_div = 39.4828
#       KL_div = 39.4179
#       KL_div = 39.3723
#       KL_div = 39.3402
# Mstep in iteration 87
# *Iteration*: 88
# Estep in iteration 88
#       KL_div = 38.9241
#       KL_div = 38.9494
#       KL_div = 38.9673
#       KL_div = 38.9800
#       KL_div = 38.9889
# Mstep in iteration 88
# *Iteration*: 89
# Estep in iteration 89
#       KL_div = 39.7797
#       KL_div = 39.6646
#       KL_div = 39.5838
#       KL_div = 39.5269
#       KL_div = 39.4869
# Mstep in iteration 89
# *Iteration*: 90
# Estep in iteration 90
#       KL_div = 38.8287
#       KL_div = 38.8733
#       KL_div = 38.9041
#       KL_div = 38.9259
#       KL_div = 38.9412
# Mstep in iteration 90
# *Iteration*: 91
# Estep in iteration 91
#       KL_div = 40.3396
#       KL_div = 40.1628
#       KL_div = 40.0403
#       KL_div = 39.9542
#       KL_div = 39.8937
# Mstep in iteration 91
# *Iteration*: 92
# Estep in iteration 92
#       KL_div = 39.1592
#       KL_div = 39.2011
#       KL_div = 39.2297
#       KL_div = 39.2498
#       KL_div = 39.2639
# Mstep in iteration 92
# *Iteration*: 93
# Estep in iteration 93
#       KL_div = 40.0420
#       KL_div = 39.9243
#       KL_div = 39.8415
#       KL_div = 39.7832
#       KL_div = 39.7421
# Mstep in iteration 93
# *Iteration*: 94
# Estep in iteration 94
#       KL_div = 39.0905
#       KL_div = 39.1347
#       KL_div = 39.1652
#       KL_div = 39.1867
#       KL_div = 39.2019
# Mstep in iteration 94
# *Iteration*: 95
# Estep in iteration 95
#       KL_div = 40.7868
#       KL_div = 40.5723
#       KL_div = 40.4237
#       KL_div = 40.3192
#       KL_div = 40.2458
# Mstep in iteration 95
# *Iteration*: 96
# Estep in iteration 96
#       KL_div = 39.4542
#       KL_div = 39.4962
#       KL_div = 39.5245
#       KL_div = 39.5444
#       KL_div = 39.5584
# Mstep in iteration 96
# *Iteration*: 97
# Estep in iteration 97
#       KL_div = 40.9433
#       KL_div = 40.7738
#       KL_div = 40.6577
#       KL_div = 40.5764
#       KL_div = 40.5192
# Mstep in iteration 97
# *Iteration*: 98
# Estep in iteration 98
#       KL_div = 38.9693
#       KL_div = 39.0732
#       KL_div = 39.1429
#       KL_div = 39.1920
#       KL_div = 39.2268
# Mstep in iteration 98
# *Iteration*: 99
# Estep in iteration 99
#       KL_div = 40.2806
#       KL_div = 40.1783
#       KL_div = 40.1074
#       KL_div = 40.0574
#       KL_div = 40.0221
# Mstep in iteration 99
# Reprojected V_b was non simetric during the exacution: 0 times using minimum tolerance of 1e-11
# Final Loss: 2793.7552
#       time for final loss computation: 0.0057 s
# Total time for GP:                     35.9881 s

# %%
# utils.save_model(model_b, './models/cell8_250ntilde_error')
# model_b = utils.load_model('./models/cell8_250ntilde_error')
xlim = None
# xlim = (1, 5)
ylim_lambda0 = None
utils.plot_loss_and_theta_notebook(model_b, figsize=(15,10), xlim=xlim, ylim_lambda0=ylim_lambda0)

# %% [markdown]
# ### Plot the Loss and Hyperparameters
#
# `VarGP` returns 2 dictionaries with the following structure:
#
# - `values_track`:
#   - `loss_track`:
#     - `logmarginal`
#     - `loglikelihood`
#     - `KL`
#   - `theta_track`:
#     - `sigma_0`
#     - `eps_0x`
#     - `eps_0y`
#     - `-2log2beta`
#     - `-log2rho2`
#     - `Amp`
#   - `f_par_track`:
#     - `logA`
#     - `loglambda0`
#
#
# - `fit_parameters`:
#   - `maxiter`,
#   - `nMstep`,
#   - `nEstep`,
#   - `kernfun`,
#   - `cellid`,
#   - `MIN_TOLERANCE`,
#   - `EIGVAL_TOL`

# %% [markdown]
# ## Evaluate the model on the test set using the explained variance and plot it

# %%
torch.set_grad_enabled(False)


# Predict and test
R_test_cell, R_pred_cell, r2, sigma_r2 = utils.test(X_test, R_test, xtilde, **model_b )


R_test_cell = R_test_cell.cpu().numpy()
R_pred_cell = R_pred_cell.cpu().numpy()
r2          = r2.cpu().numpy()
sigma_r2    = sigma_r2.cpu().numpy()

# Plot results after putting on cpu, numpy.
fig = plt.figure(figsize=(12, 8))
gs = fig.add_gridspec(5, 5,
            left=0.1, right=0.9, bottom=0.1, top=0.9,
            wspace=0.3, hspace=0.7)
dt = 0.05
time_values = dt * np.arange( len(R_pred_cell) )
ax = fig.add_subplot(gs[3:, :])
ax.plot(time_values, np.mean(R_test_cell, axis=0) / 0.05, 'o-', linewidth=1)

ax.plot(time_values, R_pred_cell / 0.05, 'o-', color='red', label='GP')
# ax.errorbar(time_values, R_predicted / 0.05, yerr=np.sqrt(sigma2_f[:,0].cpu()) / 0.05, color='red')
# ax.legend(['data', 'GP'], loc='upper right', fontsize=14)
txt = f'Pietro adjusted r^2 = {r2:.2f} ± {sigma_r2:.2f} Cell: {cellid} ntilde: {ntilde} '
ax.set_title(f'{txt}')
ax.set_ylabel('Firing rate')
ax.set_xlabel('Frames of the test sequence')
ax.grid(axis='both')
# plt.grid()
plt.legend()
plt.show()
plt.close()


a=1
# Out:
#  Pietro's model: R2 = -0.25 ± 0.00 Cell: 14 maxiter = 32, nEstep = 5, nMstep = 5
